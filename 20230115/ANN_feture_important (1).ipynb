# %%
#https://github.com/krishnaik06/AQI-Project/blob/master/ANN.ipynb

# %% [markdown]
# ## Artificial Neural Network

# %% [markdown]
# ### Apply ML algorithms
#
# - Linear Regression
# - Lasso Regression
# - Decision Tree Regressor
# - KNN Regressor
# - RandomForestRegressor
# - Xgboost Regressor
# - Huperparameter Tuning
# - ANN- Artificial Neural Network

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Real_Combine.csv')

# %%
df.shape
# Out:
# (1093, 9)

# %%
## Check for null values

sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df=df.dropna()

# %%
X=df.iloc[:,:-1] ## independent features
y=df.iloc[:,-1] ## dependent features

# %%
## check null values
X.isnull()
# Out:
#           T     TM     Tm    SLP      H     VV      V     VM
# 0     False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...
# 1088  False  False  False  False  False  False  False  False
# 1089  False  False  False  False  False  False  False  False
# 1090  False  False  False  False  False  False  False  False
# 1091  False  False  False  False  False  False  False  False
# 1092  False  False  False  False  False  False  False  False
#
# [1092 rows x 8 columns]

# %%
y.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1088    False
# 1089    False
# 1090    False
# 1091    False
# 1092    False
# Name: PM 2.5, Length: 1092, dtype: bool

# %%
sns.pairplot(df)
# Out:
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.967536  0.953719 -0.881409 -0.509299  0.640792  0.301994
# TM      0.967536  1.000000  0.892031 -0.822958 -0.586681  0.606945  0.292949
# Tm      0.953719  0.892031  1.000000 -0.917518 -0.287357  0.577240  0.296225
# SLP    -0.881409 -0.822958 -0.917518  1.000000  0.240256 -0.517915 -0.329838
# H      -0.509299 -0.586681 -0.287357  0.240256  1.000000 -0.465374 -0.380575
# VV      0.640792  0.606945  0.577240 -0.517915 -0.465374  1.000000  0.376873
# V       0.301994  0.292949  0.296225 -0.329838 -0.380575  0.376873  1.000000
# VM      0.287738  0.297011  0.266782 -0.310704 -0.362177  0.342442  0.775655
# PM 2.5 -0.631462 -0.568409 -0.673824  0.623187  0.138005 -0.573941 -0.268530
#
#               VM    PM 2.5
# T       0.287738 -0.631462
# TM      0.297011 -0.568409
# Tm      0.266782 -0.673824
# SLP    -0.310704  0.623187
# H      -0.362177  0.138005
# VV      0.342442 -0.573941
# V       0.775655 -0.268530
# VM      1.000000 -0.215854
# PM 2.5 -0.215854  1.000000

# %% [markdown]
# ### Correlation Matrix with Heatmap
# Correlation states how the features are related to each other or the target variable.
#
# Correlation can be positive (increase in one value of feature increases the value of the target variable) or negative (increase in one value of feature decreases the value of the target variable)
#
# Heatmap makes it easy to identify which features are most related to the target variable, we will plot heatmap of correlated features using the seaborn library.

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
corrmat.index
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %% [markdown]
# ### Feature Importance
# You can get the feature importance of each feature of your dataset by using the feature importance property of the model.
#
# Feature importance gives you a score for each feature of your data, the higher the score more important or relevant is the feature towards your output variable.
#
# Feature importance is an inbuilt class that comes with Tree Based Regressor, we will be using Extra Tree Regressor for extracting the top 10 features for the dataset.

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
X.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2

# %%
print(model.feature_importances_)
# Out:
# [0.18040779 0.10658098 0.18991636 0.14801523 0.089114   0.18938301
#  0.05352395 0.04305867]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# ### ANN

# %%
sns.distplot(y)
# Out:
# /var/folders/rw/8pq9jr5s1zx9tp4bv3tc92nh0000gn/T/ipykernel_5561/476133659.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y)
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='PM 2.5', ylabel='Density'>

# %% [markdown]
# ### Train Test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

# Fitting the ANN to the Training set
model_history=NN_model.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 128)               1152
#  dense_11 (Dense)            (None, 256)               33024
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  dense_13 (Dense)            (None, 256)               65792
#
#  dense_14 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 166,017
# Trainable params: 166,017
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 52/52 [==============================] - 2s 8ms/step - loss: 70.9367 - mean_absolute_error: 70.9367 - val_loss: 64.9431 - val_mean_absolute_error: 64.9431
# Epoch 2/100
# 52/52 [==============================] - 0s 6ms/step - loss: 67.8029 - mean_absolute_error: 67.8029 - val_loss: 65.2149 - val_mean_absolute_error: 65.2149
# Epoch 3/100
# 52/52 [==============================] - 0s 5ms/step - loss: 65.3343 - mean_absolute_error: 65.3343 - val_loss: 63.2445 - val_mean_absolute_error: 63.2445
# Epoch 4/100
# 52/52 [==============================] - 0s 5ms/step - loss: 64.2709 - mean_absolute_error: 64.2709 - val_loss: 63.0740 - val_mean_absolute_error: 63.0740
# Epoch 5/100
# 52/52 [==============================] - 0s 5ms/step - loss: 60.1011 - mean_absolute_error: 60.1011 - val_loss: 60.3053 - val_mean_absolute_error: 60.3053
# Epoch 6/100
# 52/52 [==============================] - 0s 5ms/step - loss: 51.0503 - mean_absolute_error: 51.0503 - val_loss: 59.0508 - val_mean_absolute_error: 59.0508
# Epoch 7/100
# 52/52 [==============================] - 0s 5ms/step - loss: 50.1983 - mean_absolute_error: 50.1983 - val_loss: 48.0350 - val_mean_absolute_error: 48.0350
# Epoch 8/100
# 52/52 [==============================] - 0s 5ms/step - loss: 48.8602 - mean_absolute_error: 48.8602 - val_loss: 45.9929 - val_mean_absolute_error: 45.9929
# Epoch 9/100
# 52/52 [==============================] - 0s 5ms/step - loss: 44.9283 - mean_absolute_error: 44.9283 - val_loss: 54.6797 - val_mean_absolute_error: 54.6797
# Epoch 10/100
# 52/52 [==============================] - 0s 6ms/step - loss: 46.0211 - mean_absolute_error: 46.0211 - val_loss: 49.0735 - val_mean_absolute_error: 49.0735
# Epoch 11/100
# 52/52 [==============================] - 0s 8ms/step - loss: 43.4262 - mean_absolute_error: 43.4262 - val_loss: 46.4223 - val_mean_absolute_error: 46.4223
# Epoch 12/100
# 52/52 [==============================] - 0s 7ms/step - loss: 44.0048 - mean_absolute_error: 44.0048 - val_loss: 45.9285 - val_mean_absolute_error: 45.9285
# Epoch 13/100
# 52/52 [==============================] - 0s 9ms/step - loss: 43.1024 - mean_absolute_error: 43.1024 - val_loss: 61.0748 - val_mean_absolute_error: 61.0748
# Epoch 14/100
# 52/52 [==============================] - 1s 20ms/step - loss: 45.4110 - mean_absolute_error: 45.4110 - val_loss: 46.7105 - val_mean_absolute_error: 46.7105
# Epoch 15/100
# 52/52 [==============================] - 1s 14ms/step - loss: 43.4655 - mean_absolute_error: 43.4655 - val_loss: 45.3421 - val_mean_absolute_error: 45.3421
# Epoch 16/100
# 52/52 [==============================] - 1s 10ms/step - loss: 43.2695 - mean_absolute_error: 43.2695 - val_loss: 56.0411 - val_mean_absolute_error: 56.0411
# Epoch 17/100
# 52/52 [==============================] - 0s 8ms/step - loss: 44.8094 - mean_absolute_error: 44.8094 - val_loss: 47.7153 - val_mean_absolute_error: 47.7153
# Epoch 18/100
# 52/52 [==============================] - 0s 9ms/step - loss: 43.3549 - mean_absolute_error: 43.3549 - val_loss: 45.3380 - val_mean_absolute_error: 45.3380
# Epoch 19/100
# 52/52 [==============================] - 0s 7ms/step - loss: 42.5512 - mean_absolute_error: 42.5512 - val_loss: 52.6825 - val_mean_absolute_error: 52.6825
# Epoch 20/100
# 52/52 [==============================] - 1s 15ms/step - loss: 46.7572 - mean_absolute_error: 46.7572 - val_loss: 44.7727 - val_mean_absolute_error: 44.7727
# Epoch 21/100
# 52/52 [==============================] - 1s 13ms/step - loss: 41.4120 - mean_absolute_error: 41.4120 - val_loss: 44.3484 - val_mean_absolute_error: 44.3484
# Epoch 22/100
# 52/52 [==============================] - 0s 9ms/step - loss: 41.6385 - mean_absolute_error: 41.6385 - val_loss: 46.3215 - val_mean_absolute_error: 46.3215
# Epoch 23/100
# 52/52 [==============================] - 0s 7ms/step - loss: 44.5728 - mean_absolute_error: 44.5728 - val_loss: 61.0413 - val_mean_absolute_error: 61.0413
# Epoch 24/100
# 52/52 [==============================] - 0s 8ms/step - loss: 45.6572 - mean_absolute_error: 45.6572 - val_loss: 44.4411 - val_mean_absolute_error: 44.4411
# Epoch 25/100
# 52/52 [==============================] - 0s 7ms/step - loss: 42.0999 - mean_absolute_error: 42.0999 - val_loss: 47.7243 - val_mean_absolute_error: 47.7243
# Epoch 26/100
# 52/52 [==============================] - 0s 5ms/step - loss: 42.0371 - mean_absolute_error: 42.0371 - val_loss: 45.8414 - val_mean_absolute_error: 45.8414
# Epoch 27/100
# 52/52 [==============================] - 0s 5ms/step - loss: 42.4350 - mean_absolute_error: 42.4350 - val_loss: 44.8361 - val_mean_absolute_error: 44.8361
# Epoch 28/100
# 52/52 [==============================] - 0s 9ms/step - loss: 41.1954 - mean_absolute_error: 41.1954 - val_loss: 44.4880 - val_mean_absolute_error: 44.4880
# Epoch 29/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.6348 - mean_absolute_error: 41.6348 - val_loss: 44.6867 - val_mean_absolute_error: 44.6867
# Epoch 30/100
# 52/52 [==============================] - 0s 5ms/step - loss: 42.0725 - mean_absolute_error: 42.0725 - val_loss: 45.1053 - val_mean_absolute_error: 45.1053
# Epoch 31/100
# 52/52 [==============================] - 0s 5ms/step - loss: 43.2326 - mean_absolute_error: 43.2326 - val_loss: 45.2489 - val_mean_absolute_error: 45.2489
# Epoch 32/100
# 52/52 [==============================] - 0s 5ms/step - loss: 43.1948 - mean_absolute_error: 43.1948 - val_loss: 44.2405 - val_mean_absolute_error: 44.2405
# Epoch 33/100
# 52/52 [==============================] - 0s 5ms/step - loss: 42.9730 - mean_absolute_error: 42.9730 - val_loss: 45.1859 - val_mean_absolute_error: 45.1859
# Epoch 34/100
# 52/52 [==============================] - 0s 5ms/step - loss: 42.1189 - mean_absolute_error: 42.1189 - val_loss: 46.4115 - val_mean_absolute_error: 46.4115
# Epoch 35/100
# 52/52 [==============================] - 0s 5ms/step - loss: 43.9594 - mean_absolute_error: 43.9594 - val_loss: 44.1959 - val_mean_absolute_error: 44.1959
# Epoch 36/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.3247 - mean_absolute_error: 41.3247 - val_loss: 45.1894 - val_mean_absolute_error: 45.1894
# Epoch 37/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.1493 - mean_absolute_error: 40.1493 - val_loss: 46.8309 - val_mean_absolute_error: 46.8309
# Epoch 38/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.2141 - mean_absolute_error: 41.2141 - val_loss: 44.4591 - val_mean_absolute_error: 44.4591
# Epoch 39/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.0538 - mean_absolute_error: 41.0538 - val_loss: 44.8956 - val_mean_absolute_error: 44.8956
# Epoch 40/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.8244 - mean_absolute_error: 40.8244 - val_loss: 46.5589 - val_mean_absolute_error: 46.5589
# Epoch 41/100
# 52/52 [==============================] - 0s 6ms/step - loss: 40.7627 - mean_absolute_error: 40.7627 - val_loss: 44.7926 - val_mean_absolute_error: 44.7926
# Epoch 42/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.6169 - mean_absolute_error: 40.6169 - val_loss: 46.1221 - val_mean_absolute_error: 46.1221
# Epoch 43/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.5142 - mean_absolute_error: 40.5142 - val_loss: 45.7903 - val_mean_absolute_error: 45.7903
# Epoch 44/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.5297 - mean_absolute_error: 39.5297 - val_loss: 44.7114 - val_mean_absolute_error: 44.7114
# Epoch 45/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.5419 - mean_absolute_error: 40.5419 - val_loss: 44.5805 - val_mean_absolute_error: 44.5805
# Epoch 46/100
# 52/52 [==============================] - 0s 8ms/step - loss: 40.6997 - mean_absolute_error: 40.6997 - val_loss: 46.2811 - val_mean_absolute_error: 46.2811
# Epoch 47/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.2979 - mean_absolute_error: 41.2979 - val_loss: 46.8957 - val_mean_absolute_error: 46.8957
# Epoch 48/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.3153 - mean_absolute_error: 40.3153 - val_loss: 46.4077 - val_mean_absolute_error: 46.4077
# Epoch 49/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.0260 - mean_absolute_error: 40.0260 - val_loss: 53.8353 - val_mean_absolute_error: 53.8353
# Epoch 50/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.6429 - mean_absolute_error: 41.6429 - val_loss: 46.0162 - val_mean_absolute_error: 46.0162
# Epoch 51/100
# 52/52 [==============================] - 0s 5ms/step - loss: 42.6628 - mean_absolute_error: 42.6628 - val_loss: 44.2661 - val_mean_absolute_error: 44.2661
# Epoch 52/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.3151 - mean_absolute_error: 39.3151 - val_loss: 44.3093 - val_mean_absolute_error: 44.3093
# Epoch 53/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.8147 - mean_absolute_error: 39.8147 - val_loss: 44.7317 - val_mean_absolute_error: 44.7317
# Epoch 54/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.4761 - mean_absolute_error: 41.4761 - val_loss: 44.4322 - val_mean_absolute_error: 44.4322
# Epoch 55/100
# 52/52 [==============================] - 0s 5ms/step - loss: 43.7904 - mean_absolute_error: 43.7904 - val_loss: 47.5058 - val_mean_absolute_error: 47.5058
# Epoch 56/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.6382 - mean_absolute_error: 41.6382 - val_loss: 44.1764 - val_mean_absolute_error: 44.1764
# Epoch 57/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.6304 - mean_absolute_error: 39.6304 - val_loss: 44.9520 - val_mean_absolute_error: 44.9520
# Epoch 58/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.9877 - mean_absolute_error: 41.9877 - val_loss: 44.6801 - val_mean_absolute_error: 44.6801
# Epoch 59/100
# 52/52 [==============================] - 0s 9ms/step - loss: 39.8516 - mean_absolute_error: 39.8516 - val_loss: 44.0352 - val_mean_absolute_error: 44.0352
# Epoch 60/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.9250 - mean_absolute_error: 39.9250 - val_loss: 46.7368 - val_mean_absolute_error: 46.7368
# Epoch 61/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.5054 - mean_absolute_error: 41.5054 - val_loss: 47.3952 - val_mean_absolute_error: 47.3952
# Epoch 62/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.2456 - mean_absolute_error: 40.2456 - val_loss: 51.5060 - val_mean_absolute_error: 51.5060
# Epoch 63/100
# 52/52 [==============================] - 0s 5ms/step - loss: 44.7101 - mean_absolute_error: 44.7101 - val_loss: 51.1350 - val_mean_absolute_error: 51.1350
# Epoch 64/100
# 52/52 [==============================] - 0s 6ms/step - loss: 39.9940 - mean_absolute_error: 39.9940 - val_loss: 48.2561 - val_mean_absolute_error: 48.2561
# Epoch 65/100
# 52/52 [==============================] - 0s 6ms/step - loss: 44.2817 - mean_absolute_error: 44.2817 - val_loss: 49.8352 - val_mean_absolute_error: 49.8352
# Epoch 66/100
# 52/52 [==============================] - 0s 7ms/step - loss: 42.4186 - mean_absolute_error: 42.4186 - val_loss: 46.0712 - val_mean_absolute_error: 46.0712
# Epoch 67/100
# 52/52 [==============================] - 0s 7ms/step - loss: 41.4142 - mean_absolute_error: 41.4142 - val_loss: 47.5378 - val_mean_absolute_error: 47.5378
# Epoch 68/100
# 52/52 [==============================] - 0s 8ms/step - loss: 39.7890 - mean_absolute_error: 39.7890 - val_loss: 49.4126 - val_mean_absolute_error: 49.4126
# Epoch 69/100
# 52/52 [==============================] - 0s 7ms/step - loss: 44.9087 - mean_absolute_error: 44.9087 - val_loss: 43.8177 - val_mean_absolute_error: 43.8177
# Epoch 70/100
# 52/52 [==============================] - 0s 6ms/step - loss: 42.1531 - mean_absolute_error: 42.1531 - val_loss: 46.8113 - val_mean_absolute_error: 46.8113
# Epoch 71/100
# 52/52 [==============================] - 0s 7ms/step - loss: 40.0250 - mean_absolute_error: 40.0250 - val_loss: 43.6167 - val_mean_absolute_error: 43.6167
# Epoch 72/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.6703 - mean_absolute_error: 39.6703 - val_loss: 43.7964 - val_mean_absolute_error: 43.7964
# Epoch 73/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.9944 - mean_absolute_error: 40.9944 - val_loss: 46.4977 - val_mean_absolute_error: 46.4977
# Epoch 74/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.1962 - mean_absolute_error: 40.1962 - val_loss: 44.8274 - val_mean_absolute_error: 44.8274
# Epoch 75/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.0850 - mean_absolute_error: 40.0850 - val_loss: 44.1598 - val_mean_absolute_error: 44.1598
# Epoch 76/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.3513 - mean_absolute_error: 39.3513 - val_loss: 51.3075 - val_mean_absolute_error: 51.3075
# Epoch 77/100
# 52/52 [==============================] - 0s 5ms/step - loss: 43.1680 - mean_absolute_error: 43.1680 - val_loss: 43.6873 - val_mean_absolute_error: 43.6873
# Epoch 78/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.0125 - mean_absolute_error: 40.0125 - val_loss: 44.5827 - val_mean_absolute_error: 44.5827
# Epoch 79/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.6777 - mean_absolute_error: 40.6777 - val_loss: 43.8000 - val_mean_absolute_error: 43.8000
# Epoch 80/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.3694 - mean_absolute_error: 39.3694 - val_loss: 43.7969 - val_mean_absolute_error: 43.7969
# Epoch 81/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.9654 - mean_absolute_error: 41.9654 - val_loss: 48.3352 - val_mean_absolute_error: 48.3352
# Epoch 82/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.1951 - mean_absolute_error: 40.1951 - val_loss: 43.8846 - val_mean_absolute_error: 43.8846
# Epoch 83/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.4921 - mean_absolute_error: 39.4921 - val_loss: 46.2035 - val_mean_absolute_error: 46.2035
# Epoch 84/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.9742 - mean_absolute_error: 40.9742 - val_loss: 43.9709 - val_mean_absolute_error: 43.9709
# Epoch 85/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.4829 - mean_absolute_error: 39.4829 - val_loss: 44.5726 - val_mean_absolute_error: 44.5726
# Epoch 86/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.4392 - mean_absolute_error: 40.4392 - val_loss: 43.5147 - val_mean_absolute_error: 43.5147
# Epoch 87/100
# 52/52 [==============================] - 0s 6ms/step - loss: 38.7047 - mean_absolute_error: 38.7047 - val_loss: 43.9679 - val_mean_absolute_error: 43.9679
# Epoch 88/100
# 52/52 [==============================] - 0s 9ms/step - loss: 38.9049 - mean_absolute_error: 38.9049 - val_loss: 43.5332 - val_mean_absolute_error: 43.5332
# Epoch 89/100
# 52/52 [==============================] - 0s 5ms/step - loss: 38.5675 - mean_absolute_error: 38.5675 - val_loss: 48.9237 - val_mean_absolute_error: 48.9238
# Epoch 90/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.1522 - mean_absolute_error: 41.1522 - val_loss: 44.0033 - val_mean_absolute_error: 44.0033
# Epoch 91/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.7001 - mean_absolute_error: 40.7001 - val_loss: 43.8480 - val_mean_absolute_error: 43.8480
# Epoch 92/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.5591 - mean_absolute_error: 39.5591 - val_loss: 43.5838 - val_mean_absolute_error: 43.5838
# Epoch 93/100
# 52/52 [==============================] - 0s 5ms/step - loss: 38.3859 - mean_absolute_error: 38.3859 - val_loss: 46.7111 - val_mean_absolute_error: 46.7111
# Epoch 94/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.4995 - mean_absolute_error: 39.4995 - val_loss: 43.8162 - val_mean_absolute_error: 43.8162
# Epoch 95/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.6771 - mean_absolute_error: 39.6771 - val_loss: 43.9869 - val_mean_absolute_error: 43.9869
# Epoch 96/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.5008 - mean_absolute_error: 39.5008 - val_loss: 45.5505 - val_mean_absolute_error: 45.5505
# Epoch 97/100
# 52/52 [==============================] - 0s 5ms/step - loss: 41.2141 - mean_absolute_error: 41.2141 - val_loss: 43.3629 - val_mean_absolute_error: 43.3629
# Epoch 98/100
# 52/52 [==============================] - 0s 5ms/step - loss: 39.3754 - mean_absolute_error: 39.3754 - val_loss: 43.4710 - val_mean_absolute_error: 43.4710
# Epoch 99/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.2295 - mean_absolute_error: 40.2295 - val_loss: 45.2551 - val_mean_absolute_error: 45.2551
# Epoch 100/100
# 52/52 [==============================] - 0s 5ms/step - loss: 40.7481 - mean_absolute_error: 40.7481 - val_loss: 43.5583 - val_mean_absolute_error: 43.5583

# %% [markdown]
# #### Model Evaluation

# %%
prediction=NN_model.predict(X_test)
# Out:
# 11/11 [==============================] - 0s 2ms/step

# %%
y_test
# Out:
# 785    104.625000
# 742    125.891667
# 748    279.600000
# 986    110.416667
# 480     31.333333
#           ...
# 492     44.125000
# 62     142.500000
# 79      65.166667
# 300     22.333333
# 194      0.000000
# Name: PM 2.5, Length: 328, dtype: float64

# %%
sns.distplot(y_test.values.reshape(-1,1)-prediction)
# Out:
# /var/folders/rw/8pq9jr5s1zx9tp4bv3tc92nh0000gn/T/ipykernel_5561/3642946253.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test.values.reshape(-1,1)-prediction)
# /Users/yosuakristianto/Documents/Code Repository/ml-cua-collection/.conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
plt.scatter(y_test,prediction)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 42.90792999422647
# MSE: 3767.4385059237375
# RMSE: 61.37946322609654

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 42.90792999422647
# MSE: 3767.4385059237375
# RMSE: 61.37946322609654

# %% [markdown]
# # Regression Evaluation Metrics
#
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 42.90792999422647
# MSE: 3767.4385059237375
# RMSE: 61.37946322609654

# %%
import pickle

# %%
# open a file, where you ant to store the data
file = open('random_forest_regression_model.pkl', 'wb')

# dump information to that file
pickle.dump(rf_random, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 5
#       2 file = open('random_forest_regression_model.pkl', 'wb')
#       4 # dump information to that file
# ----> 5 pickle.dump(rf_random, file)
#
# NameError: name 'rf_random' is not defined
